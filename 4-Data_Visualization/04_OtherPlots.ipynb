# %% [markdown]
# ## -Line plot with multi facets

# %%
# import libraries

import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load data set

dots=sns.load_dataset("dots")
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.set_theme(style="ticks")
#Defining a color palette
my_palet = sns.color_palette('rocket_r')
#plot lineplot
sns.relplot(data=dots,x="time",y="firing_rate",hue="coherence",size="choice",col="align", kind="line", 
            size_order=["T1","T2"],palette= my_palet, height=5, aspect=0.75,facet_kws=dict(sharex=False),
)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# #### Different Plots with real data set

# %%
chilla = pd.read_csv("chilla_data.csv")
chilla.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group    Network  \
# 0     to boost my skill set     Unemplyed           B+    U-fone
# 1     to boost my skill set       Student           B+    U-fone
# 2  Switch my field of study      Employed           B+      Zong
# 3     to boost my skill set      Employed           O+    U-fone
# 4     to boost my skill set       Student           A-  Mobilink
#
#   Prepaid or Postpaid  ... Your favorite programming language? Marital Status  \
# ...

# %%
chilla.columns
# Out:
# Index(['Gender', 'Location', 'Age', 'Qualification_completed',
#        'field_of_study', 'Purpose_for_chilla', 'What are you?', 'Blood group ',
#        'Network', 'Prepaid or Postpaid', 'Which PC are you using?', 'Glasses',
#        'First line of code', 'Your favorite programming language?',
#        'Marital Status', 'Vaccinated', 'Area',
#        'Research/Working experience (Float/Int) years',
#        'Age (years)-Float/Int', 'Weight in kg', 'Height', 'coding hours',
#        'Load shedding'],
#       dtype='object')

# %% [markdown]
# #### Changing Binary optionset data to Numeric data

# %%
field = chilla['field_of_study']
vaccinated = chilla['Vaccinated'].map({'Yes': 1, 'No': 0})
gender =chilla['Gender'].map({'Male': 1, 'Female': 0})
glasses = chilla['Glasses'].map({'Yes': 1, 'No': 0})
marital = chilla['Marital Status'].map({'Yes': 1, 'No': 0})
area = chilla['Area'].map({'Urbun': 1, 'Rural': 0})

# %% [markdown]
# #### Scatter Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")


# Draw a scatter plot while assigning point colors and sizes to different variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="First line of code", y="Height",
                hue=gender, size=vaccinated,
                hue_order=gender, color='red',
                sizes=(1, 8), linewidth=0,
                data=chilla, ax=ax)
# Out:
# <AxesSubplot:xlabel='First line of code', ylabel='Height'>

# %% [markdown]
# #### Line Plot

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

chilla = pd.read_csv("chilla_data.csv")

# Plot the responses for different events and regions
sns.lineplot(x="Age", y="Weight in kg",
             hue=area, style=gender,
             data=chilla)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Weight in kg'>

# %% [markdown]
# #### Displot

# %%
import seaborn as sns

sns.displot(
    chilla, x="Age", col=area, row=gender,
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)
plt.figure(figsize=(18,6))

# %% [markdown]
# #### Violinplot

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=chilla, x="Age", y="coding hours", hue=gender,
               split=True, inner="quart", linewidth=1,
               )
sns.despine(left=True)

# %% [markdown]
# #### lmPlot

# %%
import seaborn as sns
chilla = pd.read_csv("chilla_data.csv")

sns.set_theme(style="ticks")



# Show the results of a linear regression within each dataset
sns.lmplot(x="Height", y="Weight in kg", col="Age", hue="Age", data=chilla,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# #### Jointplot

# %%
import numpy as np
import seaborn as sns
sns.set_theme(style="ticks")



sns.jointplot(data=chilla, x="Age", y="Height", color="#4CB391")

# %% [markdown]
# #### Histplot

# %%
# new data set Dimonds


diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
