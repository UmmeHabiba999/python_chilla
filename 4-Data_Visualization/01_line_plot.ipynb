# %% [markdown]
# - categorical variables/coloms dont show in describe
# - Numeric variable are mostly drawn on Y axis,
# - Categorical variables are mostly drawn on X-axis or in hue
# - we never use Numerical variables/coloms with numerc values in "hue"

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
#load dataset

iris_data = sns.load_dataset("iris")
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##  -Adding Name of the graph

# %%
# draw a line plot

sns.lineplot(x="sepal_length" ,y="sepal_width" , data= iris_data)
plt.title("Iris Flowers Graph")
plt.show()

# %% [markdown]
# ## - Adding x and y limits

# %%
# draw a line plot

sns.lineplot(x="sepal_length" ,y="sepal_width" , data= iris_data)
plt.title("Iris Flowers Graph")

plt.xlim(2)
plt.ylim(1)
plt.show()

# %% [markdown]
# ## - set styles
#
# - Dark Grid
# - Whitegrid
# - Dark
# - White
# - Ticks

# %%
# draw a line plot
sns.lineplot(x="sepal_length" ,y="sepal_width" , data= iris_data)
plt.title("Iris Flowers Graph")
sns.set_style("dark")
# sns.set_style(style=None , rc= None)

plt.show()

# %% [markdown]
# #### with Different style "white grid"

# %%
# draw a line plot
sns.lineplot(x="sepal_length" ,y="sepal_width" , data= iris_data,ci=None)
plt.title("Iris Flowers Graph")
sns.set_style("whitegrid")
# sns.set_style(style=None , rc= None)

plt.show()

# %% [markdown]
# ## - size of figure

# %%
#size of figure

plt.figure(figsize=(10,6))

# draw a line plot

sns.lineplot(x="sepal_length" ,y="sepal_width" , data= iris_data)
plt.title("Iris Flowers Graph")
sns.set_style("dark")

plt.show()

# %% [markdown]
# ### Practice with different dataset

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load Dataset

chilla_data = pd.read_csv('chilla_data.csv')
chilla_data.head()
# Out:
#    Gender  Location    Age Qualification_completed    field_of_study  \
# 0    Male  Pakistan  36-40                 Masters  Natural Sciences
# 1    Male  Pakistan  26-30               Bachelors             CS/IT
# 2    Male  Pakistan  31-35                 Masters       Enginnering
# 3  Female  Pakistan  31-35                 Masters             CS/IT
# 4  Female  Pakistan  26-30                 Masters       Enginnering
#
#          Purpose_for_chilla What are you? Blood group    Network  \
# 0     to boost my skill set     Unemplyed           B+    U-fone
# 1     to boost my skill set       Student           B+    U-fone
# 2  Switch my field of study      Employed           B+      Zong
# 3     to boost my skill set      Employed           O+    U-fone
# 4     to boost my skill set       Student           A-  Mobilink
#
#   Prepaid or Postpaid  ... Your favorite programming language? Marital Status  \
# ...

# %% [markdown]
# ### Changing Binary optionset data to Numeric data

# %%
field = chilla_data['field_of_study']
marital = chilla_data['Marital Status'].map({'Yes': 1, 'No': 0})
vaccinated = chilla_data['Vaccinated'].map({'Yes': 1, 'No': 0})
gender = chilla_data['Gender'].map({'Male':1 ,'Female':0})
area = chilla_data['Area'].map({'Urbun': 1, 'Rural': 0})
glasses = chilla_data['Glasses'].map({'Yes': 1, 'No': 0})

# %% [markdown]
# #### Line Plot

# %%
# select axis

xs = field
ys = chilla_data['coding hours']

plt.figure(figsize= (20,8))
a = sns.lineplot(x= xs,y=ys,data= chilla_data, ci=None)
a.set(xlabel='field of study', ylabel='Coding Hours')

# Add Title of Graph
plt.title('field of study vs coding hours')

plt.show()

# %%
xs= chilla_data['What are you?']
ys= chilla_data['Purpose_for_chilla']
plt.figure(figsize=(12,6))
# xs, ys = zip(*sorted(zip(xs, ys)))
sns.lineplot(y=xs, x=ys, data =chilla_data )
plt.title('qualification  and purpose')
plt.show()

# %%
xs = chilla_data['Area']
ys = chilla_data['Load shedding']

plt.figure(figsize=(14,6))
a =sns.lineplot(x=xs, y=ys, data =chilla_data, ci=None )
a.set(xlabel='Area', ylabel='Loadshedding')
plt.title('Loadshedding in Different Areas')
plt.show()

# %%
xs = chilla_data['Area']
ys = chilla_data['coding hours']

plt.figure(figsize=(14,6))
a=sns.lineplot(x=xs,y=ys,data=chilla_data,ci= None)
a.set(xlabel='Area' , ylabel='Coding Hours')

plt.show()

# %%
xs= chilla_data['field_of_study']
ys= glasses
xs, ys = zip(*sorted(zip(xs, ys)))
plt.figure(figsize=(14,8))
a=sns.lineplot(x=xs, y=ys, data =chilla_data )
a.set(xlabel='Field of study' , ylabel='Glasses')
plt.title('field of study vs Glasses')
plt.show()
