# %% [markdown]
# ## Students t-tests
# 1. One Sample t-test
# 2. Two sample t-test
#    1. unpaired or independent t-test
#    2. paired or dependent/ relational t-test

# %% [markdown]
# ### 1. One sample t-test
# Tests a sample with a non standard value
#
# **Assumptions**
# 1. Observations in each sample are independent and identically distributed(iid)
# 2. Observations in each sample are Normally distributed
# 3. Observations in each sample have the same varience
#
# **Interpretation**
#
# H0: The means of samples are equal to the known value \
# H1: The means of samples are unequal to known values.

# %% [markdown]
# ### One-sample t-test

# %%
# import libraries

import seaborn as sns
import numpy as np
import pandas as pd
from scipy.stats import ttest_1samp

# %%
# load data set

boat = sns.load_dataset('titanic')
boat.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Dropping null values of Age and fare 
boat.dropna(subset=['age','fare'], axis=0, inplace=True)
boat.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           530
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
# taking subsets

boat_subset = boat[['sex', 'age']]
boat_subset.head()
# Out:
#       sex   age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
boat_subset.describe()
# Out:
#               age
# count  714.000000
# mean    29.699118
# std     14.526497
# min      0.420000
# 25%     20.125000
# 50%     28.000000
# 75%     38.000000
# max     80.000000

# %%
# Checking and comparing age with a known value 

from scipy.stats import ttest_1samp
stat, p = ttest_1samp(boat_subset['age'], 45)
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
  print('Probably the same distribution')
else:
  print('Probably different distribution')
# Out:
# stat=-28.145, p=0.000
# Probably different distribution

# %% [markdown]
# Above results are not quiet correct, because data is not normalized,standard deviation value is greater, first normalize the data then apply test.

# %% [markdown]
# ### 2. Two sample t-test
# **Independent/unpaired student's t-test**
#
# **Assumptions**
# 1. Observations in each sample are independent and identically distributed(iid)
# 2. Observations in each sample are Normally distributed
# 3. Observations in each sample have the same varience
#
# **Interpretation**
#
# **H0:** The means of samples are equal to the known value \
# **H1:** The means of samples are unequal to known values.

# %% [markdown]
# > In two sample t-test we compare 2 different samples, e.g Male and Female compare their age or fare

# %%
# compare age and fare of male Vs Female passenger

# splitting data sets
df_male = boat_subset.loc[boat_subset['sex']=='male']
df_female = boat_subset.loc[boat_subset['sex']=='female']

# %%
# import library

from scipy.stats import ttest_ind
stat, p = ttest_ind(df_male['age'], df_female['age'])
print('stat=%.3f, p=%.3f' % (stat, p))

# Adding conditional argument for ease
if p > 0.05:
  print('Probably the same distribution')
else:
  print('Probably different distribution')
# Out:
# stat=2.499, p=0.013
# Probably different distribution

# %% [markdown]
# > From above results we can see that male and female are differently distributed, we can also see it through EDA

# %%
# lets see through EDA

df_male.describe()
# Out:
#               age
# count  453.000000
# mean    30.726645
# std     14.678201
# min      0.420000
# 25%     21.000000
# 50%     29.000000
# 75%     39.000000
# max     80.000000

# %%
df_female.describe()
# Out:
#               age
# count  261.000000
# mean    27.915709
# std     14.110146
# min      0.750000
# 25%     18.000000
# 50%     27.000000
# 75%     37.000000
# max     63.000000

# %% [markdown]
# ### 2. Two sample t-test
# **Paired/Dependent/ Relational student's t-test**\
# Tests whether the means of 2 paired samples are significantly diffrent.
# **Assumptions**
# 1. Observations in each sample are independent and identically distributed(iid)
# 2. Observations in each sample are Normally distributed
# 3. Observations in each sample have the same varience.
# 4. Observations across each sample are paired.
#
# **Interpretation**
#
# **H0:** The means of samples are equal.\
# **H1:** The means of samples are unequal.

# %%
# in paired ttest we will compare only male passengers from first class and 2nd class, 
# because its paired ttest meaning within one sample
df_male.head()
# Out:
#      sex   age
# 0   male  22.0
# 4   male  35.0
# 6   male  54.0
# 7   male   2.0
# 12  male  20.0

# %%
# In above data we only have sex and age cols, but here we need Class data to compare, so, lets use the main dataframe

df_male = boat.loc[boat['sex']=='male']
df_male.head(10)
# Out:
#     survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3  male  22.0      1      0   7.2500        S   Third
# 4          0       3  male  35.0      0      0   8.0500        S   Third
# 6          0       1  male  54.0      0      0  51.8625        S   First
# 7          0       3  male   2.0      3      1  21.0750        S   Third
# 12         0       3  male  20.0      0      0   8.0500        S   Third
# 13         0       3  male  39.0      1      5  31.2750        S   Third
# 16         0       3  male   2.0      4      1  29.1250        Q   Third
# 20         0       2  male  35.0      0      0  26.0000        S  Second
# 21         1       2  male  34.0      0      0  13.0000        S  Second
# 23         1       1  male  28.0      0      0  35.5000        S   First
#
#       who  adult_male deck  embark_town alive  alone
# 0     man        True  NaN  Southampton    no  False
# 4     man        True  NaN  Southampton    no   True
# 6     man        True    E  Southampton    no   True
# 7   child       False  NaN  Southampton    no  False
# 12    man        True  NaN  Southampton    no   True
# 13    man        True  NaN  Southampton    no  False
# 16  child       False  NaN   Queenstown    no  False
# 20    man        True  NaN  Southampton    no   True
# 21    man        True    D  Southampton   yes   True
# 23    man        True    A  Southampton   yes   True

# %%
# select only 2 classes

df_male_first = df_male.loc[df_male['class']=='First']
df_male_second = df_male.loc[df_male['class']=='Second']
df_male_third = df_male.loc[df_male['class']=='Third']

# %%
df_male_first.head()
# Out:
#     survived  pclass   sex   age  sibsp  parch      fare embarked  class  who  \
# 6          0       1  male  54.0      0      0   51.8625        S  First  man
# 23         1       1  male  28.0      0      0   35.5000        S  First  man
# 27         0       1  male  19.0      3      2  263.0000        S  First  man
# 30         0       1  male  40.0      0      0   27.7208        C  First  man
# 34         0       1  male  28.0      1      0   82.1708        C  First  man
#
#     adult_male deck  embark_town alive  alone
# 6         True    E  Southampton    no   True
# 23        True    A  Southampton   yes   True
# 27        True    C  Southampton    no  False
# 30        True  NaN    Cherbourg    no   True
# 34        True  NaN    Cherbourg    no  False

# %%
df_male_second.head()
# Out:
#     survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 20         0       2  male  35.0      0      0  26.0        S  Second  man
# 21         1       2  male  34.0      0      0  13.0        S  Second  man
# 33         0       2  male  66.0      0      0  10.5        S  Second  man
# 70         0       2  male  32.0      0      0  10.5        S  Second  man
# 72         0       2  male  21.0      0      0  73.5        S  Second  man
#
#     adult_male deck  embark_town alive  alone
# 20        True  NaN  Southampton    no   True
# 21        True    D  Southampton   yes   True
# 33        True  NaN  Southampton    no   True
# 70        True  NaN  Southampton    no   True
# 72        True  NaN  Southampton    no   True

# %%
df_male_third.head()
# Out:
#     survived  pclass   sex   age  sibsp  parch    fare embarked  class    who  \
# 0          0       3  male  22.0      1      0   7.250        S  Third    man
# 4          0       3  male  35.0      0      0   8.050        S  Third    man
# 7          0       3  male   2.0      3      1  21.075        S  Third  child
# 12         0       3  male  20.0      0      0   8.050        S  Third    man
# 13         0       3  male  39.0      1      5  31.275        S  Third    man
#
#     adult_male deck  embark_town alive  alone
# 0         True  NaN  Southampton    no  False
# 4         True  NaN  Southampton    no   True
# 7        False  NaN  Southampton    no  False
# 12        True  NaN  Southampton    no   True
# 13        True  NaN  Southampton    no  False

# %%
# import library

from scipy.stats import ttest_rel
# Apply test to compare class First and Third

stat, p = ttest_rel(df_male_first['age'], df_male_third['age'])
print('stat=%.3f, p=%.3f' % (stat, p))

# Adding conditional argument for ease
if p > 0.05:
  print('Probably the same distribution')
else:
  print('Probably different distribution')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# e:\Python ka Chilla course\Python_Chilla\data_normality_tests\3-ttests.ipynb Cell 25 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/e%3A/Python%20ka%20Chilla%20course/Python_Chilla/data_normality_tests/3-ttests.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a> from scipy.stats import ttest_rel
#       <a href='vscode-notebook-cell:/e%3A/Python%20ka%20Chilla%20course/Python_Chilla/data_normality_tests/3-ttests.ipynb#X33sZmlsZQ%3D%3D?line=3'>4</a> # Apply test to compare class First and Third
# ----> <a href='vscode-notebook-cell:/e%3A/Python%20ka%20Chilla%20course/Python_Chilla/data_normality_tests/3-ttests.ipynb#X33sZmlsZQ%3D%3D?line=5'>6</a> stat, p = ttest_rel(df_male_first['age'], df_male_third['age'])
#       <a href='vscode-notebook-cell:/e%3A/Python%20ka%20Chilla%20course/Python_Chilla/data_normality_tests/3-ttests.ipynb#X33sZmlsZQ%3D%3D?line=6'>7</a> print('stat=%.3f, p=%.3f' % (stat, p))
#       <a href='vscode-notebook-cell:/e%3A/Python%20ka%20Chilla%20course/Python_Chilla/data_normality_tests/3-ttests.ipynb#X33sZmlsZQ%3D%3D?line=8'>9</a> # Adding conditional argument for ease
#
# File c:\Users\AhmadLap\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_stats_py.py:6501, in ttest_rel(a, b, axis, nan_policy, alternative)
#    6499 nb = _get_len(b, axis, "second argument")
#    6500 if na != nb:
# -> 6501     raise ValueError('unequal length arrays')
#    6503 if na == 0:
#    6504     return _ttest_nans(a, b, axis, Ttest_relResult)
#
# ValueError: unequal length arrays

# %% [markdown]
# > Above code returns an error because number of rows/instences should be equal to apply ttest.
# > Now, we'll take sample of 1st and 2nd class with equal number of rows to compare.

# %%
print("Total number of instances in First Class Are:" , df_male_first.shape)
print("Total number of instances in Second Class Are:" , df_male_second.shape)
# Out:
# Total number of instances in First Class Are: (101, 15)
# Total number of instances in Second Class Are: (99, 15)

# %%
# since the total nmber of rows in df_male_second is "99" , so, lets take sample of atleast 90
df_1st =  df_male_first.sample(n=99)
df_2nd =  df_male_second.sample(n=99)

# %%
# Now lets do the test again

# import library

from scipy.stats import ttest_rel
# Apply test to compare class First and Third

stat, p = ttest_rel(df_1st['age'], df_2nd['age'])
print('stat=%.3f, p=%.3f' % (stat, p))

# Adding conditional argument for ease
if p > 0.05:
  print('Probably the same distribution')
else:
  print('Probably different distribution')
# Out:
# stat=4.741, p=0.000
# Probably different distribution
